# %%
from bs4 import BeautifulSoup
import requests

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer


import scipy.sparse as ssp
import pandas as pd
import json

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from unicodedata import normalize

# the following code is used since I had problem with the nltk.download method 
import ssl
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

import nltk 
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/monti03/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/monti03/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
file_ = open('DG-Miner_miner-disease-gene.tsv')

# %%
diseases = set()
lines = file_.read().split('\n')[1:]
for line in lines:
    if(line == ''):
        continue
    gene = line.split('\t')[0][5:]
    diseases.add(gene)

# %%
null_values = set()
http_null = set()
founded = 0
not_f = 0
data_dict = {}
for row in diseases:
    page = requests.get('https://www.ncbi.nlm.nih.gov/medgen/?term='+row)
    print(row)
    soup = BeautifulSoup(page.content, 'html.parser')
    if(soup == None):
        http_null.add(row)
        print('{}: page not found'.format())
        continue
    
    results = soup.find('div', class_='portlet_content')
    if(results == None or results.text == ''):
        print(results)
        null_values.add(row)
        not_f += 1
        print('{}: field not found'.format(row))
        continue
    res = results.text
    founded += 1
    
    print('founded: {}\t not_founded: {}\ttotal: {}'.format(founded, not_f, not_f+founded))
    data_dict[row] = res
# Out:
# founded: 5253	 not_founded: 19	total: 5272
# D011038
# founded: 5254	 not_founded: 19	total: 5273
# D002873
# founded: 5255	 not_founded: 19	total: 5274
# C563865
# founded: 5256	 not_founded: 19	total: 5275
# C565311
# founded: 5257	 not_founded: 19	total: 5276
# D007969
# founded: 5258	 not_founded: 19	total: 5277
# 607447
# founded: 5259	 not_founded: 19	total: 5278
# C565831
# founded: 5260	 not_founded: 19	total: 5279
# D001228
# founded: 5261	 not_founded: 19	total: 5280
# D002177
# founded: 5262	 not_founded: 19	total: 5281
# D009395
# founded: 5263	 not_founded: 19	total: 5282
# D017282
# founded: 5264	 not_founded: 19	total: 5283
# C535441
# founded: 5265	 not_founded: 19	total: 5284
# D006946
# founded: 5266	 not_founded: 19	total: 5285
# D012874
# founded: 5267	 not_founded: 19	total: 5286
# 264070
# founded: 5268	 not_founded: 19	total: 5287
# 212050
# founded: 5269	 not_founded: 19	total: 5288
# C536122
# founded: 5270	 not_founded: 19	total: 5289
# D000015
# founded: 5271	 not_founded: 19	total: 5290
# C567753
# founded: 5272	 not_founded: 19	total: 5291
# D011085
# founded: 5273	 not_founded: 19	total: 5292
# D029242
# founded: 5274	 not_founded: 19	total: 5293
# D003323
# founded: 5275	 not_founded: 19	total: 5294
# C536029
# founded: 5276	 not_founded: 19	total: 5295
# C562694
# founded: 5277	 not_founded: 19	total: 5296
# D004653
# founded: 5278	 not_founded: 19	total: 5297
# D001254
# founded: 5279	 not_founded: 19	total: 5298
# C535413
# founded: 5280	 not_founded: 19	total: 5299
# 610297
# founded: 5281	 not_founded: 19	total: 5300
# D020762
# founded: 5282	 not_founded: 19	total: 5301
# D006408
# founded: 5283	 not_founded: 19	total: 5302
# C563714
# founded: 5284	 not_founded: 19	total: 5303
# D006970
# founded: 5285	 not_founded: 19	total: 5304
# C562768
# founded: 5286	 not_founded: 19	total: 5305
# D010864
# founded: 5287	 not_founded: 19	total: 5306
# C563627
# founded: 5288	 not_founded: 19	total: 5307
# D020016
# founded: 5289	 not_founded: 19	total: 5308
# D004684
# founded: 5290	 not_founded: 19	total: 5309
# C564404
# founded: 5291	 not_founded: 19	total: 5310
# C536296
# founded: 5292	 not_founded: 19	total: 5311
# D002239
# founded: 5293	 not_founded: 19	total: 5312
# 613456
# founded: 5294	 not_founded: 19	total: 5313
# D020806
# founded: 5295	 not_founded: 19	total: 5314
# D013492
# founded: 5296	 not_founded: 19	total: 5315
# C566310
# founded: 5297	 not_founded: 19	total: 5316
# C535956
# founded: 5298	 not_founded: 19	total: 5317
# C565316
# founded: 5299	 not_founded: 19	total: 5318
# D004660
# founded: 5300	 not_founded: 19	total: 5319
# D012735
# founded: 5301	 not_founded: 19	total: 5320
# D007160
# founded: 5302	 not_founded: 19	total: 5321
# C537757
# founded: 5303	 not_founded: 19	total: 5322
# D010855
# founded: 5304	 not_founded: 19	total: 5323
# C565218
# founded: 5305	 not_founded: 19	total: 5324
# D004409
# founded: 5306	 not_founded: 19	total: 5325
# D009755
# founded: 5307	 not_founded: 19	total: 5326
# D054364
# founded: 5308	 not_founded: 19	total: 5327
# C536842
# founded: 5309	 not_founded: 19	total: 5328
# D016553
# founded: 5310	 not_founded: 19	total: 5329
# C563693
# founded: 5311	 not_founded: 19	total: 5330
# D055092
# founded: 5312	 not_founded: 19	total: 5331
# C564333
# founded: 5313	 not_founded: 19	total: 5332
# D007815
# founded: 5314	 not_founded: 19	total: 5333
# C535344
# founded: 5315	 not_founded: 19	total: 5334
# C563160
# founded: 5316	 not_founded: 19	total: 5335
# D017093
# founded: 5317	 not_founded: 19	total: 5336
# C535420
# founded: 5318	 not_founded: 19	total: 5337
# C535737
# founded: 5319	 not_founded: 19	total: 5338
# D019873
# founded: 5320	 not_founded: 19	total: 5339
# D010254
# founded: 5321	 not_founded: 19	total: 5340
# D053360
# founded: 5322	 not_founded: 19	total: 5341
# D000751
# founded: 5323	 not_founded: 19	total: 5342
# D007003
# founded: 5324	 not_founded: 19	total: 5343
# C563822
# founded: 5325	 not_founded: 19	total: 5344
# D000788
# founded: 5326	 not_founded: 19	total: 5345
# D007153
# founded: 5327	 not_founded: 19	total: 5346
# C548080
# founded: 5328	 not_founded: 19	total: 5347
# C562573
# founded: 5329	 not_founded: 19	total: 5348
# D020215
# founded: 5330	 not_founded: 19	total: 5349
# C536309
# founded: 5331	 not_founded: 19	total: 5350
# 611809
# founded: 5332	 not_founded: 19	total: 5351
# C538353
# founded: 5333	 not_founded: 19	total: 5352
# D016891
# founded: 5334	 not_founded: 19	total: 5353
# D016116
# founded: 5335	 not_founded: 19	total: 5354
# 275350
# founded: 5336	 not_founded: 19	total: 5355
# D014806
# founded: 5337	 not_founded: 19	total: 5356
# C536225
# founded: 5338	 not_founded: 19	total: 5357
# D007948
# founded: 5339	 not_founded: 19	total: 5358
# C535397
# founded: 5340	 not_founded: 19	total: 5359
# C537045
# founded: 5341	 not_founded: 19	total: 5360
# D004169
# founded: 5342	 not_founded: 19	total: 5361
# D001264
# founded: 5343	 not_founded: 19	total: 5362
# D020031
# founded: 5344	 not_founded: 19	total: 5363
# C564008
# founded: 5345	 not_founded: 19	total: 5364
# D003329
# founded: 5346	 not_founded: 19	total: 5365
# C565611
# founded: 5347	 not_founded: 19	total: 5366
# D007319
# founded: 5348	 not_founded: 19	total: 5367
# D012488
# founded: 5349	 not_founded: 19	total: 5368
# C565840
# founded: 5350	 not_founded: 19	total: 5369
# D056486
# founded: 5351	 not_founded: 19	total: 5370
# D006349
# founded: 5352	 not_founded: 19	total: 5371
# 613790
# founded: 5353	 not_founded: 19	total: 5372
# D009542
# founded: 5354	 not_founded: 19	total: 5373
# D015212
# founded: 5355	 not_founded: 19	total: 5374
# D015812
# founded: 5356	 not_founded: 19	total: 5375
# D053584
# founded: 5357	 not_founded: 19	total: 5376
# C567842
# founded: 5358	 not_founded: 19	total: 5377
# D013344
# founded: 5359	 not_founded: 19	total: 5378
# C536974
# founded: 5360	 not_founded: 19	total: 5379
# C565752
# founded: 5361	 not_founded: 19	total: 5380
# C567025
# founded: 5362	 not_founded: 19	total: 5381
# C535521
# founded: 5363	 not_founded: 19	total: 5382
# C537128
# founded: 5364	 not_founded: 19	total: 5383
# C563755
# founded: 5365	 not_founded: 19	total: 5384
# C566766
# founded: 5366	 not_founded: 19	total: 5385
# D018192
# founded: 5367	 not_founded: 19	total: 5386
# C538275
# founded: 5368	 not_founded: 19	total: 5387
# D004842
# founded: 5369	 not_founded: 19	total: 5388
# D006819
# founded: 5370	 not_founded: 19	total: 5389
# D053560
# founded: 5371	 not_founded: 19	total: 5390
# C538212
# founded: 5372	 not_founded: 19	total: 5391
# D030321
# founded: 5373	 not_founded: 19	total: 5392
# D009976
# founded: 5374	 not_founded: 19	total: 5393
# C567582
# founded: 5375	 not_founded: 19	total: 5394
# 602032
# founded: 5376	 not_founded: 19	total: 5395
# D008551
# founded: 5377	 not_founded: 19	total: 5396
# D005158
# founded: 5378	 not_founded: 19	total: 5397
# C567616
# founded: 5379	 not_founded: 19	total: 5398
# C562434
# founded: 5380	 not_founded: 19	total: 5399
# D013547
# founded: 5381	 not_founded: 19	total: 5400
# 606657
# founded: 5382	 not_founded: 19	total: 5401
# D055496
# founded: 5383	 not_founded: 19	total: 5402
# D003316
# founded: 5384	 not_founded: 19	total: 5403
# D011504
# founded: 5385	 not_founded: 19	total: 5404
# C536170
# founded: 5386	 not_founded: 19	total: 5405
# C535897
# founded: 5387	 not_founded: 19	total: 5406
# C537207
# founded: 5388	 not_founded: 19	total: 5407
# D016388
# founded: 5389	 not_founded: 19	total: 5408
# D011668
# founded: 5390	 not_founded: 19	total: 5409
# C567572
# founded: 5391	 not_founded: 19	total: 5410
# C535912
# founded: 5392	 not_founded: 19	total: 5411
# C535301
# founded: 5393	 not_founded: 19	total: 5412
# C566996
# founded: 5394	 not_founded: 19	total: 5413
# D011111
# founded: 5395	 not_founded: 19	total: 5414
# D007415
# founded: 5396	 not_founded: 19	total: 5415
# D014456
# founded: 5397	 not_founded: 19	total: 5416
# D000303
# founded: 5398	 not_founded: 19	total: 5417
# D009375
# founded: 5399	 not_founded: 19	total: 5418
# D021183
# founded: 5400	 not_founded: 19	total: 5419
# D018754
# founded: 5401	 not_founded: 19	total: 5420
# C535761
# founded: 5402	 not_founded: 19	total: 5421
# D002286
# founded: 5403	 not_founded: 19	total: 5422
# D014949
# founded: 5404	 not_founded: 19	total: 5423
# C563273
# founded: 5405	 not_founded: 19	total: 5424
# C565780
# founded: 5406	 not_founded: 19	total: 5425
# D004198
# founded: 5407	 not_founded: 19	total: 5426
# C537968
# founded: 5408	 not_founded: 19	total: 5427
# D010842
# founded: 5409	 not_founded: 19	total: 5428
# C537201
# founded: 5410	 not_founded: 19	total: 5429
# D006505
# founded: 5411	 not_founded: 19	total: 5430
# D055623
# founded: 5412	 not_founded: 19	total: 5431
# D016757
# founded: 5413	 not_founded: 19	total: 5432
# D014524
# founded: 5414	 not_founded: 19	total: 5433
# D002925
# founded: 5415	 not_founded: 19	total: 5434
# D000753
# founded: 5416	 not_founded: 19	total: 5435
# C567262
# founded: 5417	 not_founded: 19	total: 5436
# 612319
# founded: 5418	 not_founded: 19	total: 5437
# C567675
# founded: 5419	 not_founded: 19	total: 5438
# 613703
# founded: 5420	 not_founded: 19	total: 5439
# D014394
# founded: 5421	 not_founded: 19	total: 5440
# D048629
# founded: 5422	 not_founded: 19	total: 5441
# D007418
# founded: 5423	 not_founded: 19	total: 5442
# D008545
# founded: 5424	 not_founded: 19	total: 5443
# C537839
# founded: 5425	 not_founded: 19	total: 5444
# D012848
# founded: 5426	 not_founded: 19	total: 5445
# D002341
# founded: 5427	 not_founded: 19	total: 5446
# D016603
# founded: 5428	 not_founded: 19	total: 5447
# D006192
# founded: 5429	 not_founded: 19	total: 5448
# C537841
# founded: 5430	 not_founded: 19	total: 5449
# 201750
# founded: 5431	 not_founded: 19	total: 5450
# C566121
# founded: 5432	 not_founded: 19	total: 5451
# C535442
# founded: 5433	 not_founded: 19	total: 5452
# 609813
# founded: 5434	 not_founded: 19	total: 5453
# C562938
# founded: 5435	 not_founded: 19	total: 5454
# D015658
# founded: 5436	 not_founded: 19	total: 5455
# D016142
# founded: 5437	 not_founded: 19	total: 5456
# C567672
# founded: 5438	 not_founded: 19	total: 5457
# D009377
# founded: 5439	 not_founded: 19	total: 5458
# D007172
# founded: 5440	 not_founded: 19	total: 5459
# 211750
# founded: 5441	 not_founded: 19	total: 5460
# C537403
# founded: 5442	 not_founded: 19	total: 5461
# D015043
# founded: 5443	 not_founded: 19	total: 5462
# D008382
# founded: 5444	 not_founded: 19	total: 5463
# C567643
# founded: 5445	 not_founded: 19	total: 5464
# 215140
# founded: 5446	 not_founded: 19	total: 5465
# D020195
# founded: 5447	 not_founded: 19	total: 5466
# C567839
# founded: 5448	 not_founded: 19	total: 5467
# D020336
# founded: 5449	 not_founded: 19	total: 5468
# D020918
# founded: 5450	 not_founded: 19	total: 5469
# C566452
# founded: 5451	 not_founded: 19	total: 5470
# D010244
# founded: 5452	 not_founded: 19	total: 5471
# C536300
# founded: 5453	 not_founded: 19	total: 5472
# C563897
# founded: 5454	 not_founded: 19	total: 5473
# C562639
# founded: 5455	 not_founded: 19	total: 5474
# D061325
# founded: 5456	 not_founded: 19	total: 5475
# D020919
# founded: 5457	 not_founded: 19	total: 5476
# C563930
# founded: 5458	 not_founded: 19	total: 5477
# D018437
# founded: 5459	 not_founded: 19	total: 5478
# C563250
# founded: 5460	 not_founded: 19	total: 5479
# C535741
# founded: 5461	 not_founded: 19	total: 5480
# D015433
# founded: 5462	 not_founded: 19	total: 5481
# D014594
# founded: 5463	 not_founded: 19	total: 5482
# C567857
# founded: 5464	 not_founded: 19	total: 5483
# C562385
# founded: 5465	 not_founded: 19	total: 5484
# C567407
# founded: 5466	 not_founded: 19	total: 5485
# D010031
# founded: 5467	 not_founded: 19	total: 5486
# 613718
# founded: 5468	 not_founded: 19	total: 5487
# D014115
# founded: 5469	 not_founded: 19	total: 5488
# C563417
# founded: 5470	 not_founded: 19	total: 5489
# D001989
# founded: 5471	 not_founded: 19	total: 5490
# D010490
# founded: 5472	 not_founded: 19	total: 5491
# D054437
# founded: 5473	 not_founded: 19	total: 5492
# D045743
# founded: 5474	 not_founded: 19	total: 5493
# C536312
# founded: 5475	 not_founded: 19	total: 5494
# D009459
# founded: 5476	 not_founded: 19	total: 5495
# C567809
# founded: 5477	 not_founded: 19	total: 5496
# C536530
# founded: 5478	 not_founded: 19	total: 5497
# C567735
# founded: 5479	 not_founded: 19	total: 5498
# C566545
# founded: 5480	 not_founded: 19	total: 5499
# D020773
# founded: 5481	 not_founded: 19	total: 5500
# D006521
# founded: 5482	 not_founded: 19	total: 5501
# C564603
# founded: 5483	 not_founded: 19	total: 5502
# C565826
# founded: 5484	 not_founded: 19	total: 5503
# C535434
# founded: 5485	 not_founded: 19	total: 5504
# C563740
# founded: 5486	 not_founded: 19	total: 5505
# D018827
# founded: 5487	 not_founded: 19	total: 5506
# D012133
# founded: 5488	 not_founded: 19	total: 5507
# D054989
# founded: 5489	 not_founded: 19	total: 5508
# D015160
# founded: 5490	 not_founded: 19	total: 5509
# D017190
# founded: 5491	 not_founded: 19	total: 5510
# D000292
# founded: 5492	 not_founded: 19	total: 5511
# 235700
# founded: 5493	 not_founded: 19	total: 5512
# D000592
# founded: 5494	 not_founded: 19	total: 5513
# D005383
# founded: 5495	 not_founded: 19	total: 5514
# D004240
# founded: 5496	 not_founded: 19	total: 5515
# D057774
# founded: 5497	 not_founded: 19	total: 5516
# 233300
# founded: 5498	 not_founded: 19	total: 5517
# C564352
# founded: 5499	 not_founded: 19	total: 5518
# D011027
# founded: 5500	 not_founded: 19	total: 5519
# C565152
# founded: 5501	 not_founded: 19	total: 5520
# D017036
# founded: 5502	 not_founded: 19	total: 5521
# 613157
# founded: 5503	 not_founded: 19	total: 5522
# C566005
# founded: 5504	 not_founded: 19	total: 5523
# 601072
# founded: 5505	 not_founded: 19	total: 5524
# D013322
# founded: 5506	 not_founded: 19	total: 5525
# D020165
# founded: 5507	 not_founded: 19	total: 5526
# D004679
# founded: 5508	 not_founded: 19	total: 5527
# D014126
# founded: 5509	 not_founded: 19	total: 5528
# D009182
# founded: 5510	 not_founded: 19	total: 5529
# D004195
# founded: 5511	 not_founded: 19	total: 5530
# C565185
# founded: 5512	 not_founded: 19	total: 5531
# C567513
# founded: 5513	 not_founded: 19	total: 5532
# D014397
# founded: 5514	 not_founded: 19	total: 5533
# 194300
# founded: 5515	 not_founded: 19	total: 5534
# D007925
# founded: 5516	 not_founded: 19	total: 5535
# D016399
# founded: 5517	 not_founded: 19	total: 5536
# C566968
# founded: 5518	 not_founded: 19	total: 5537
# C535836
# founded: 5519	 not_founded: 19	total: 5538
# C564390
# founded: 5520	 not_founded: 19	total: 5539
# D014985
# founded: 5521	 not_founded: 19	total: 5540
# D010998
# founded: 5522	 not_founded: 19	total: 5541
# C537505
# founded: 5523	 not_founded: 19	total: 5542
# 253290
# founded: 5524	 not_founded: 19	total: 5543
# C538012
# founded: 5525	 not_founded: 19	total: 5544
# D013167
# founded: 5526	 not_founded: 19	total: 5545
# C538556
# founded: 5527	 not_founded: 19	total: 5546
# C567166
# founded: 5528	 not_founded: 19	total: 5547
# D018233
# founded: 5529	 not_founded: 19	total: 5548
# C567383
# founded: 5530	 not_founded: 19	total: 5549
# D052880
# founded: 5531	 not_founded: 19	total: 5550
# D003244
# founded: 5532	 not_founded: 19	total: 5551
# D013345
# founded: 5533	 not_founded: 19	total: 5552
# C565360
# founded: 5534	 not_founded: 19	total: 5553
# 613471
# founded: 5535	 not_founded: 19	total: 5554
# 613159
# founded: 5536	 not_founded: 19	total: 5555
# 613690
# founded: 5537	 not_founded: 19	total: 5556
# D014718
# founded: 5538	 not_founded: 19	total: 5557
# C566293
# founded: 5539	 not_founded: 19	total: 5558
# C536961
# founded: 5540	 not_founded: 19	total: 5559
# D016460
# founded: 5541	 not_founded: 19	total: 5560
# D013705
# founded: 5542	 not_founded: 19	total: 5561
# C564399
# founded: 5543	 not_founded: 19	total: 5562
# 613661
# founded: 5544	 not_founded: 19	total: 5563
# C536357
# founded: 5545	 not_founded: 19	total: 5564
# C566910
# founded: 5546	 not_founded: 19	total: 5565
# D004420
# founded: 5547	 not_founded: 19	total: 5566
# D012829
# founded: 5548	 not_founded: 19	total: 5567
# D020967
# founded: 5549	 not_founded: 19	total: 5568
# D013031
# founded: 5550	 not_founded: 19	total: 5569
# D010850
# founded: 5551	 not_founded: 19	total: 5570
# C563907
# founded: 5552	 not_founded: 19	total: 5571
# C537560
# founded: 5553	 not_founded: 19	total: 5572
# D017096
# founded: 5554	 not_founded: 19	total: 5573
# D012729
# founded: 5555	 not_founded: 19	total: 5574
# D020144
# founded: 5556	 not_founded: 19	total: 5575
# D012222
# founded: 5557	 not_founded: 19	total: 5576
# D004412
# founded: 5558	 not_founded: 19	total: 5577
# D044342
# founded: 5559	 not_founded: 19	total: 5578
# D004387
# founded: 5560	 not_founded: 19	total: 5579
# D042882
# founded: 5561	 not_founded: 19	total: 5580
# C565784
# founded: 5562	 not_founded: 19	total: 5581
# C562733
# founded: 5563	 not_founded: 19	total: 5582
# D048550
# founded: 5564	 not_founded: 19	total: 5583
# 611377
# founded: 5565	 not_founded: 19	total: 5584
# D011020
# founded: 5566	 not_founded: 19	total: 5585
# C535282
# founded: 5567	 not_founded: 19	total: 5586
# D031300
# founded: 5568	 not_founded: 19	total: 5587
# D020345
# founded: 5569	 not_founded: 19	total: 5588
# D012852
# founded: 5570	 not_founded: 19	total: 5589
# C537143
# founded: 5571	 not_founded: 19	total: 5590
# D020158
# founded: 5572	 not_founded: 19	total: 5591
# D005177
# founded: 5573	 not_founded: 19	total: 5592
# D020520
# founded: 5574	 not_founded: 19	total: 5593
# D014029
# founded: 5575	 not_founded: 19	total: 5594
# C567492
# founded: 5576	 not_founded: 19	total: 5595
# C535395
# founded: 5577	 not_founded: 19	total: 5596
# C538539
# founded: 5578	 not_founded: 19	total: 5597
# C567595
# founded: 5579	 not_founded: 19	total: 5598
# C535480
# founded: 5580	 not_founded: 19	total: 5599
# D019694
# founded: 5581	 not_founded: 19	total: 5600
# C563786
# founded: 5582	 not_founded: 19	total: 5601
# C535944
# founded: 5583	 not_founded: 19	total: 5602
# 271245
# founded: 5584	 not_founded: 19	total: 5603
# D019337
# founded: 5585	 not_founded: 19	total: 5604
# D009410
# founded: 5586	 not_founded: 19	total: 5605
# D009087
# founded: 5587	 not_founded: 19	total: 5606
# D018239
# founded: 5588	 not_founded: 19	total: 5607
# C536467
# founded: 5589	 not_founded: 19	total: 5608
# C567337
# founded: 5590	 not_founded: 19	total: 5609
# D000848
# founded: 5591	 not_founded: 19	total: 5610
# C565375
# founded: 5592	 not_founded: 19	total: 5611
# C565238
# founded: 5593	 not_founded: 19	total: 5612
# C538236
# founded: 5594	 not_founded: 19	total: 5613
# D012772
# founded: 5595	 not_founded: 19	total: 5614
# D001984
# founded: 5596	 not_founded: 19	total: 5615
# D003645
# founded: 5597	 not_founded: 19	total: 5616
# 613717
# founded: 5598	 not_founded: 19	total: 5617
# C563481
# founded: 5599	 not_founded: 19	total: 5618
# C563685
# founded: 5600	 not_founded: 19	total: 5619
# D028921
# founded: 5601	 not_founded: 19	total: 5620
# C567767
# founded: 5602	 not_founded: 19	total: 5621
# D041781
# founded: 5603	 not_founded: 19	total: 5622
# C535374
# founded: 5604	 not_founded: 19	total: 5623
# D007184
# founded: 5605	 not_founded: 19	total: 5624
# D003291
# founded: 5606	 not_founded: 19	total: 5625
# D018352
# founded: 5607	 not_founded: 19	total: 5626
# 151900
# founded: 5608	 not_founded: 19	total: 5627
# D005119
# founded: 5609	 not_founded: 19	total: 5628
# D001862
# founded: 5610	 not_founded: 19	total: 5629
# C535788
# founded: 5611	 not_founded: 19	total: 5630
# C567277
# founded: 5612	 not_founded: 19	total: 5631
# 613611
# founded: 5613	 not_founded: 19	total: 5632
# C537738
# founded: 5614	 not_founded: 19	total: 5633
# D018287
# founded: 5615	 not_founded: 19	total: 5634
# C535932
# founded: 5616	 not_founded: 19	total: 5635
# D004942
# founded: 5617	 not_founded: 19	total: 5636
# D012207
# founded: 5618	 not_founded: 19	total: 5637
# D001768
# founded: 5619	 not_founded: 19	total: 5638
# C566331
# founded: 5620	 not_founded: 19	total: 5639
# D009202
# founded: 5621	 not_founded: 19	total: 5640
# D007973
# founded: 5622	 not_founded: 19	total: 5641
# D020788
# founded: 5623	 not_founded: 19	total: 5642
# D006086
# founded: 5624	 not_founded: 19	total: 5643
# D020953
# founded: 5625	 not_founded: 19	total: 5644
# C565449
# founded: 5626	 not_founded: 19	total: 5645
# D008865
# founded: 5627	 not_founded: 19	total: 5646
# D015418
# founded: 5628	 not_founded: 19	total: 5647
# 610725
# founded: 5629	 not_founded: 19	total: 5648
# D051270
# founded: 5630	 not_founded: 19	total: 5649
# D012628
# founded: 5631	 not_founded: 19	total: 5650
# C567343
# founded: 5632	 not_founded: 19	total: 5651
# D005494
# founded: 5633	 not_founded: 19	total: 5652
# C563461
# founded: 5634	 not_founded: 19	total: 5653
# D012818
# founded: 5635	 not_founded: 19	total: 5654
# 604273
# founded: 5636	 not_founded: 19	total: 5655
# C567351
# founded: 5637	 not_founded: 19	total: 5656
# D003680
# founded: 5638	 not_founded: 19	total: 5657
# C567499
# founded: 5639	 not_founded: 19	total: 5658
# D007953
# founded: 5640	 not_founded: 19	total: 5659
# C538385
# founded: 5641	 not_founded: 19	total: 5660
# C537686
# founded: 5642	 not_founded: 19	total: 5661
# D013160
# founded: 5643	 not_founded: 19	total: 5662
# D007951
# founded: 5644	 not_founded: 19	total: 5663
# 108120
# founded: 5645	 not_founded: 19	total: 5664

# %%
data_dict[list(data_dict.keys())[10]]
# Out:
# 'Fanconi anemia (FA) is characterized by physical abnormalities, bone marrow failure, and increased risk for malignancy. Physical abnormalities, present in approximately 75% of affected individuals, include one or more of the following: short stature, abnormal skin pigmentation, skeletal malformations of the upper and lower limbs, microcephaly, and ophthalmic and genitourinary tract anomalies. Progressive bone marrow failure with pancytopenia typically presents in the first decade, often initially with thrombocytopenia or leukopenia. The incidence of acute myeloid leukemia is 13% by age 50 years. Solid tumors – particularly of the head and neck, skin, gastrointestinal tract, and genitourinary tract – are more common in individuals with FA.\xa0[from GeneReviews]'

# %%
len(list(data_dict.keys()))
# Out:
# 5645

# %%
with open('data_description.json', 'w') as fp:
    json.dump(data_dict, fp)

# %%
with open('null_description.txt', 'w') as fp:
    for code in null_values:
        fp.write('\n'+code)

# %%
with open('null_description_page.txt', 'w') as fp:
    for code in http_null:
        fp.write('\n'+code)

# %%
with open('data_description.json') as f:
  data_dict = json.load(f)

# %%
disease_ids = sorted(list(data_dict.keys()))

# %%
disease_ids[-1]
# Out:
# 'ease(MESH)'

# %%
''' 
    there are three type of returned texts:
    - the complete description of the disease
    - TO_UPDATE_TEXT
    - TO_REMOVE_TEXT

    the second case means that we have more diseases related to that diseaseID: in
        this case I have to get the description of the diseases
    the third case instead means that there where no results for the required 
        diseaseID, so I have to remove them.
'''
TO_UPDATE_TEXT = '\n\n\nDatabase: \n\nSelect\nBioSystems\nBooks\nClinVar\ndbGaP\nGene\nGTR\nMeSH\nOMIM\nPMC\nPubMed\n\n\n\n\nOption: \n\n\n\n\n\nFind items\n\n\n'

TO_REMOVE_TEXT = '[All Fields])\n\nSearch\n\n\n                See more...\n            \n'

to_update = set()
to_remove = set()

for disease_id in disease_ids:
    if(TO_UPDATE_TEXT == data_dict[disease_id]):
        to_update.add(disease_id)
    elif(TO_REMOVE_TEXT in data_dict[disease_id]):
        to_remove.add(disease_id)

# %%
# remove diseases
for disease_id in to_remove:
    if(disease_id in data_dict):
        del data_dict[disease_id]
    else:
        print('error: {} key not present'.format(disease_id))

del data_dict['ease(MESH)']

# %%
# get the descriptions in the case of TO_UPDATE_TEXT
for disease_id in to_update:
    page = requests.get('https://www.ncbi.nlm.nih.gov/medgen/?term='+disease_id)
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.findAll(class_='rprt')
    
    at_least_one_description = False
    tmp_des = '' 
    tmp_title = ''
    for r in results:
        title = r.find(class_='rslt').find(class_='title').text
        des_div = r.find(class_='rslt').find(class_='concept-def')
        des = ''
        if(des_div != None):
            des = des_div.text
            at_least_one_description = True

        tmp_title = tmp_title + ' ' + title 
        tmp_des = tmp_des + ' ' + des

    if(at_least_one_description):
        data_dict[disease_id] = tmp_title + ' ' + tmp_des

# %%
TO_UPDATE_TEXT = '\n\n\nDatabase: \n\nSelect\nBioSystems\nBooks\nClinVar\ndbGaP\nGene\nGTR\nMeSH\nOMIM\nPMC\nPubMed\n\n\n\n\nOption: \n\n\n\n\n\nFind items\n\n\n'

keys = set(data_dict.keys())

'''
    if for instance no one of the associated diseases has a description, we remove 
    the entry
'''
for disease_id in keys:
    if(TO_UPDATE_TEXT == data_dict[disease_id]):
        del data_dict[disease_id]

# %%
with open('data_description_updated.json', 'w') as fp:
    json.dump(data_dict, fp)

# %%
disease_ids = sorted(list(data_dict.keys()))
with open('disease_ids_order.txt', 'w') as fp:
    for code in disease_ids:
        fp.write(code+'\n')

# %%
with open('data_description_updated.json') as f:
  data_dict = json.load(f)
  disease_ids = sorted(list(data_dict.keys()))

# %%
lemmatizer = WordNetLemmatizer()

# apply normalization to the text
def normalize_(text):
    # here I replace all the chars with accents with the normal chars and I 
    # remove all utf-8 symbols (for insance I remove \u3010 that represents '[' ) 
    text = normalize('NFKD', text).encode('ascii','ignore').decode('utf-8')

    # in order to avoid to differentiate for instance dog from Dog
    # I use the text.lower() method 
    text = text.lower()
    text = text.strip()
    
    # replace punctuation and other symbols with spaces 
    text = text.translate(text.maketrans('"$&#[]-,*:{;}()/|<@>=!?.\n', "                         ")) 
    while ('  ' not in text):
        # replace double spaces with single spaces
        text.replace('  ', ' ')

    lemmatized_text = ''
    word_list = word_tokenize(text)
    for word in word_list:
        # the the lem of the single term
        lemmatized_term = lemmatizer.lemmatize(word)
        # append to the other lemmatized terms
        lemmatized_text = lemmatized_text + ' ' + lemmatized_term

    return lemmatized_text

# %%
normalized_texts = []
with open('normalized_texts.txt', 'w') as fp:
    for disease_id in disease_ids:
        text = data_dict[disease_id]
        normalized_text = normalize_(text)
        fp.write(normalized_text+'\n')
        normalized_texts.append(normalized_text)

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(normalized_texts)

# %%
X
# Out:
# <5469x33306 sparse matrix of type '<class 'numpy.float64'>'
# 	with 229748 stored elements in Compressed Sparse Row format>

# %%
ssp.save_npz('tf_idf_data', X)

# %%
r = 2151
svd = TruncatedSVD(r)
Y_to_norm = svd.fit_transform(X)
normalizer = Normalizer()
Y = normalizer.fit_transform(Y_to_norm)

var_explained = svd.explained_variance_ratio_.sum()
print(var_explained)
# Out:
# 0.8501041445409021

# %%
Y.tofile('tf_idf_data_SVD')
